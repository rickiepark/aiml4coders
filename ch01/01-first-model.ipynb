# %% [markdown]
# # 1장. 텐서플로 소개

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://nbviewer.jupyter.org/github/rickiepark/aiml4coders/blob/main/ch01/01-1-first-model.ipynb"><img src="https://jupyter.org/assets/share.png" width="61" />주피터 노트북 뷰어로 보기</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/github/rickiepark/aiml4coders/blob/main/ch01/01-1-first-model.ipynb"><img src="https://www.tensorflow.org/images/colab_logo_32px.png" />구글 코랩(Colab)에서 실행하기</a>
#   </td>
# </table>

# %% [markdown]
# ## 머신러닝 시작하기

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# %%
dense = Dense(units=1, input_shape=[1])
model = Sequential([dense])
# Out:
# 2022-02-10 00:49:18.403947: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model.compile(optimizer='sgd', loss='mean_squared_error')

# %%
xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

# %%
model.fit(xs, ys, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 204ms/step - loss: 19.5546
# Epoch 2/500
# 1/1 [==============================] - 0s 3ms/step - loss: 15.6487
# Epoch 3/500
# 1/1 [==============================] - 0s 2ms/step - loss: 12.5703
# Epoch 4/500
# 1/1 [==============================] - 0s 3ms/step - loss: 10.1430
# Epoch 5/500
# 1/1 [==============================] - 0s 2ms/step - loss: 8.2282
# Epoch 6/500
# 1/1 [==============================] - 0s 3ms/step - loss: 6.7166
# Epoch 7/500
# 1/1 [==============================] - 0s 2ms/step - loss: 5.5223
# Epoch 8/500
# 1/1 [==============================] - 0s 2ms/step - loss: 4.5779
# Epoch 9/500
# 1/1 [==============================] - 0s 2ms/step - loss: 3.8300
# Epoch 10/500
# 1/1 [==============================] - 0s 2ms/step - loss: 3.2369
# Epoch 11/500
# 1/1 [==============================] - 0s 2ms/step - loss: 2.7658
# Epoch 12/500
# 1/1 [==============================] - 0s 3ms/step - loss: 2.3905
# ...

# %%
print(model.predict([10.0]))
# Out:
# [[18.980743]]

# %%
print("신경망이 학습한 것: {}".format(dense.get_weights()))
# Out:
# 신경망이 학습한 것: [array([[1.9972092]], dtype=float32), array([-0.99134755], dtype=float32)]

# %%
print("신경망이 학습한 것: {}".format(model.layers[0].get_weights()))
# Out:
# 신경망이 학습한 것: [array([[1.9972092]], dtype=float32), array([-0.99134755], dtype=float32)]
